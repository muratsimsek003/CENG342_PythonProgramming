# %% [markdown]
# # Week-5 Object Oriented Programming

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Python Classes/Objects**
#
# Python is an object oriented programming language.
#
# Almost everything in Python is an object, with its properties and methods.
#
# A Class is like an object constructor.

# %% [markdown]
# A class is a collection of objects or you can say it is a
# blueprint of objects defining the common attributes and
# behavior Now the question arises, how do you do that?
# Class
# is defined under a Class Keyword

# %% [markdown]
# Classes are the building blocks in Object Oriented Programming.
#
# Classes can be seen as blueprints from which you create your Instances.

# %% [markdown]
# Create Class

# %%
#Create Class:



class Students:
  #attribute= age, address, name
  #behaviour =pass

  pass

# %% [markdown]
# Create Object

# %%
obj=Students()

# %%
obj

# %%
class Footballer:
  football_club="fenerbahce"
  age=21

# %%
footballer=Footballer()

# %%
footballer.age
# Out:
# 21

# %%
footballer.football_club
# Out:
# 'fenerbahce'

# %% [markdown]
# New Class

# %%
class Square:
  edge=5
  area=0
  def area1(self):
    self.area=self.edge*self.edge   #5*5
    print("Area:", self.area)

# %%
s1=Square()

# %%
s1

# %%
s1.edge
# Out:
# 5

# %%
s1.area
# Out:
# 0

# %%
s1.area1()
# Out:
# Area: 25

# %%
x=int(input("Write edge value:"))
# Out:
# Write edge value:10

# %%
s1.edge=x

# %%
s1.area1()
# Out:
# Area: 100

# %%
s1.edge=15248
s1.area1()
# Out:
# Area: 232501504

# %% [markdown]
# New Class

# %%
class Emp:

  age=25
  salary=1000

  def ageSalaryRatio(self):
    a=self.age/self.salary
    print("method:", a)

# %%
emp=Emp()

# %%
emp.salary
# Out:
# 1000

# %%
emp.age
# Out:
# 25

# %%
emp.ageSalaryRatio()
# Out:
# method: 0.025

# %% [markdown]
# New Class

# %% [markdown]
# **The __init__() Function**
#
#
#
# All classes have a function called __init__(), which is always executed when the class is being initiated.
#
# Use the __init__() function to assign values to object properties, or other operations that are necessary to do when the object is being created:

# %%
class Employers:
  def __init__(self, name, surname, age):
    self.name=name
    self.surname=surname
    self.age=age

# %%
emp1=Employers("murat", "simsek", 40)

# %%
emp1.age
# Out:
# 40

# %%
emp1.name
# Out:
# 'murat'

# %%
emp1.surname
# Out:
# 'simsek'

# %% [markdown]
# New class

# %%
class Person:
  def __init__(self,name, age):
    self.name=name
    self.age=age

# %%
p1=Person("John", 36)

# %%
p2=Person("Huseyin", 22)

# %%
p3=Person("Ali", 20)

# %%
print(p1.name)
# Out:
# John

# %%
print(p2.name)
# Out:
# Huseyin

# %%
print(p3.name)
# Out:
# Ali

# %% [markdown]
# **The self Parameter**
#
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class:

# %%
class Person:
  def __init__(self, name, age):
    self.name=name
    self.age=age

  def myfunc(self):
    print("Hello my name is "+ self.name)

# %%
person=Person("murat", 40)

# %%
person.myfunc()
# Out:
# Hello my name is murat

# %%
class Animal:

  def __init__(self,a,b):
    self.name=a
    self.age=b

  def getAge(self):
    print(" ")
    return self.age

  def getName(self):
    print(self.name)

# %%
animal1=Animal("dog",2)

# %%
animal1.getAge()
# Out:
# 2

# %%
animal1.getName()
# Out:
# dog

# %%
a2=Animal("cat", 4)
a2.getName()
# Out:
# cat

# %% [markdown]
# New class

# %%
class MyNum:
  def __init__(self):
    print("Calling the __init__() constructor!\n")
    self.val=0

  def increment(self):
    self.val=self.val+1
    print(self.val)

# %%
mynum=MyNum()
# Out:
# Calling the __init__() constructor!

# %%
mynum.increment()
# Out:
# 14

# %% [markdown]
# New class

# %%
class MyNum:
  def __init__(self,value):
    try:
      value=int(value)
    except ValueError:
      value=0
    self.value=value
  
  def increment(self):
    self.value=self.value+1
    print(self.value)

# %%
number=MyNum(10)

# %%
number.increment()
# Out:
# 11

# %%
number1=MyNum("adkjasşldlşsaldşsaklşdasklşdaskl")

# %%
number1.increment()
# Out:
# 1

# %% [markdown]
# New Class

# %%
class MyNumber:
  def __init__(self,  value):
    self.value=int(value)

  def increment(self):
    self.value=self.value+1
    print(self.value)

# %%
number=MyNumber(10)

# %%
number.increment()
# Out:
# 11

# %%
number3=MyNumber("sadsadsadsadasdasdasdasdasd")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-f1eb7ed991b1> in <module>
# ----> 1 number3=MyNumber("sadsadsadsadasdasdasdasdasd")
#
# <ipython-input-78-406c8892ec91> in __init__(self, value)
#       1 class MyNumber:
#       2   def __init__(self,  value):
# ----> 3     self.value=int(value)
#       4
#       5   def increment(self):
#
# ValueError: invalid literal for int() with base 10: 'sadsadsadsadasdasdasdasdasd'

# %%
class MyNumber:
  def __init__(self, value):
    try:
      value=int(value)
    except ValueError:
      value=0
    self.value=value

  def increment(self):
    self.value=self.value+1
    print(self.value)

# %%
a=MyNumber(10)

# %%
a.increment()
# Out:
# 14

# %%
a3=MyNumber("asdasdıopsaşdsaşşasdasd")

# %%
a3.increment()
# Out:
# 1

# %%
a4=MyNumber("Murat")

# %%
a4.increment()
# Out:
# 1

# %% [markdown]
# New Class

# %%
class Yourclass:
  classy=10

  def set_val(self):
    self.insty=100
    print(self.insty)

# %%
obj=Yourclass()

# %%
obj.classy
# Out:
# 10

# %%
obj.set_val()
# Out:
# 100

# %%
obj.insty
# Out:
# 100

# %% [markdown]
# New Class

# %%
class Car:

  def __init__(self, manufacturer, model, year):
    self.manufacturer=manufacturer
    self.model=model
    self.year=year
    self.odometer_reading=0

  def welcome(self):
    print("welcome our car class")

  def getInformation(self):
    long_name=str(self.year)+ " " + self.manufacturer+ " "+self.model

    return long_name.title()

  def read_odometer(self):
    print("Car has "+ str(self.odometer_reading)+ "km on it")

  def update_odometer(self, kilometer):

    if kilometer>=self.odometer_reading:
      self.odometer_reading=kilometer
    else:
      print("There is no change")

  def increment_odometer(self, kilometer):
    self.odometer_reading+=kilometer

# %%
my_car=Car("mercedes","c200",2022)

# %%
my_car.manufacturer
# Out:
# 'mercedes'

# %%
my_car.model
# Out:
# 'c200'

# %%
my_car.year
# Out:
# 2022

# %%
my_car.welcome()
# Out:
# welcome our car class

# %%
my_car.getInformation()
# Out:
# '2022 Mercedes C200'

# %%
my_car.read_odometer()
# Out:
# Car has 0km on it

# %%
my_car.odometer_reading
# Out:
# 0

# %%
my_car.odometer_reading=25

# %%
my_car.read_odometer()
# Out:
# Car has 25km on it

# %%
my_car.update_odometer(50)

# %%
my_car.increment_odometer(50)

# %%
my_car.read_odometer()
# Out:
# Car has 100km on it
