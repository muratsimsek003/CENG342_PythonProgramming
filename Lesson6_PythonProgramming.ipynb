# %% [markdown]
# #**Inheritance**

# %% [markdown]
# Inheritance is the capability of one class to derive or inherit the properties from another class.
#
# Benefits of inheritance are:
#
# It represents real-world relationships well.
#
# It provides the reusability of a code. We don’t have to write the same code again and again. Also, it allows us to add more features to a class without modifying it.
#
# It is transitive in nature, which means that if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A.

# %%
# Class BaseClass:
  # def adasdasdasdas:
    #asdasdasdasdas

#Class DerivedClass(BaseClass):
     #def dadsadadasdasd:
       #adadasdasdasdas

# %% [markdown]
# **Creating a Parent Class**
#
# Creating a Person class with Display methods.

# %%
class Person:

  #constructor
  def __init__(self, name,id):
    self.name=name
    self.id=id
  #to check if this person is an employee
  def display(self):
    print(self.name,self.id)

# %%
obj=Person("Murat", 123)

# %%
obj.id
# Out:
# 123

# %%
obj.name
# Out:
# 'Murat'

# %%
obj.display()
# Out:
# Murat 123

# %%
person=Person("Mehmet", 456)

# %%
person.name
# Out:
# 'Mehmet'

# %%
person.id
# Out:
# 456

# %%
person.display()
# Out:
# Mehmet 456

# %% [markdown]
# **Creating a Child Class**
#
#
# Here Emp is another class which is going to inherit the properties of the Person class(base class).

# %%
class Emp(Person):
  def Print(self):
    print("Emp class called")

# %%
emp=Emp("Murat",123)

# %%
emp.display()
# Out:
# Murat 123

# %%
emp.Print()
# Out:
# Emp class called

# %%
emp.name
# Out:
# 'Murat'

# %%
emp.id
# Out:
# 123

# %%
emp=Emp("Murat", 115)

# %%
emp.display()
# Out:
# Murat 115

# %% [markdown]
# ##New Class

# %%
#Parent Class
class Company:
  #contructor
  def __init__(self, name):
    self.name=name
    print("Company class is created")

  def section(self):
    print("Company section")

  def admin(self):
    print("Company admin")

# %% [markdown]
# The super() function is a special function that allows you to call a method from the parent class. In this example, call the __init__() method from Company, which gives an AI instance all the attributes defined in that method.
# the name super() comes from a convention of calling the parent class a superclass  and the child class a subclass.

# %%
#Child Class
class AI(Company):
  def __init__(self):
    super().__init__(self)
    print("child class is created which name is AI")

  def machinelearning(self):
    print("Using machine learning")

  def deeplearning(self):
    print("Using deep learning")

# %%
com=Company("Murat")
# Out:
# Company class is created

# %%
ai=AI()
# Out:
# Company class is created
# child class is created which name is AI

# %%
ai.section()
# Out:
# Company section

# %%
ai.name

# %%
ai.admin()
# Out:
# Company admin

# %%
ai.deeplearning()
# Out:
# Using deep learning

# %%
ai.machinelearning()
# Out:
# Using machine learning

# %%
#Parent Class 

class Animal:
  def __init__(self):
    print("animal is created")
  
  def toString(self):
    print("animal")
  
  def walk(self):
    print("animal walks")

# %%
#child class

class Monkey(Animal):
  def __init__(self):
    super().__init__() #use init  of parent class (Animal)
    print("monkey is created")

  def toString(self):
    print("monkey")

  def climb(self):
    print("monkey can climb")

#child class

class Bird(Animal):
  def __init__(self):
    super().__init__()
    print("bird is created")
  
  def fly(self):
    print("Birds can fly")

# %%
animal=Animal()
# Out:
# animal is created

# %%
bird=Bird()
# Out:
# animal is created
# bird is created

# %%
monkey=Monkey()
# Out:
# animal is created
# monkey is created

# %%
monkey.walk()
# Out:
# animal walks

# %%
m1=Monkey()
# Out:
# animal is created
# monkey is created

# %%
m1.toString()
# Out:
# monkey

# %%
m1.climb()
# Out:
# monkey can climb

# %%
bird.fly()
# Out:
# Birds can fly

# %%
class Person(object):
  def isEmployee(self):
    print("person class")

class Employee(object):
  def isEmployee(self):
    print("Employee class")


class Human(Employee,Person):
  pass

# %%
p1=Human()

# %%
p1.isEmployee()
# Out:
# Employee class

# %% [markdown]
# #New Class

# %%
class Person:
  #constructor

  def __init__(self,name):
    self.name=name


  #to get name
  def getName(self):
    return self.name

  #To check if this person is an employee

  def isEmployee(self):
    return False

#Inherited or Subclass 
class Employee(Person):

  #Here we return true


  def isEmployee(self):
    return True

# %%
emp=Employee("Murat")

# %%
emp.isEmployee()
# Out:
# True

# %%
person=Person("Ahmet")

# %%
person.isEmployee()
# Out:
# False

# %%
print(emp.getName(), emp.isEmployee())
# Out:
# Murat True

# %% [markdown]
# ## New Class

# %%
#Parent class

class Person:
  #constructor
  def __init__(self,name,idnumber):
    self.name=name
    self.idnumber=idnumber

  def display(self):
    print(self.name)
    print(self.idnumber)

#child class

class Employee(Person):
  def __init__(self, name,idnumber,salary, post):
    self.salary=salary
    self.post=post

    #invoking the __init__ of parent class
    Person.__init__(self,name,idnumber)

# %%
obj=Employee("Murat",8855,300,"academician")

# %%
obj.display()
# Out:
# Murat
# 8855

# %% [markdown]
# ##New Class  (Multiple Inheritance)

# %%
#Python example to show the working of multiple inheritance

class Base1:
  def __init__(self):
    self.str1= "Python"
    print("Base1 Class")
  def method(self):
    print("first method")


class Base2:
  def __init__(self):
    self.str2="OOP"
    print("Base2 Class")
  def method(self):
    print("second method")



class Derived(Base1, Base2):
  def __init__(self):

    #calling construuctors of Base1 and Base2 classes
    Base1.__init__(self)
    Base2.__init__(self)
    print("Derived Class")

  def printStrs(self):
    print(self.str1, self.str2)

# %%
obj=Derived()
# Out:
# Base1 Class
# Base2 Class
# Derived Class

# %%
obj.printStrs()
# Out:
# Python OOP

# %%
obj.method()
# Out:
# first method

# %% [markdown]
# #New Class

# %%
class Emp():
  def __init__(self,id,name,Add):
    self.id=id
    self.name=name
    self.Add=Add

class Freelance(Emp):
  def __init__(self, id, name, Add, Emails):
    super().__init__(id,name,Add)
    self.Emails=Emails

# %%
freelance=Freelance(123,"Murat","Ankara","murat.simsek@ostimteknik.edu.tr")

# %%
print("The ID is:", freelance.id)
print("The name is:", freelance.name)
print("The Address is:", freelance.Add)
print("The Email is:", freelance.Emails)
# Out:
# The ID is: 123
# The name is: Murat
# The Address is: Ankara
# The Email is: murat.simsek@ostimteknik.edu.tr

# %% [markdown]
# ##New Class

# %%
class Main1:
  def __init__(self):
    self.str1="Python"
    print("Main1")
  def method(self):
    print("method 1")


class Main2:
  def __init__(self):
    self.str2="Programming"
    print("Main2")

  def method(self):
    print("method 2")

class Derived(Main1,Main2):
  def __init__(self):

    Main2.__init__(self)
    print("Derived")


  def printStrs(self):
    print(self.str1, self.str2)

# %%
derived=Derived()
# Out:
# Main2
# Derived

# %% [markdown]
# #Write a script of multiple inheritance class design
# # This is your homework
