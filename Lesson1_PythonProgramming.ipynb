# %% [markdown]
#  # Python Programming Lesson-1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ## Variables and Variable Types

# %%
x=5
type(x)
# Out:
# int

# %%
y=3.14
type(y)
# Out:
# float

# %%
lesson="CENG342"
type(lesson)
# Out:
# str

# %%
var=True
type(var)
# Out:
# bool

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=5
y=2
print(x+y)
# Out:
# 7

# %%
print(x-y)
# Out:
# 3

# %%
print(x*y)
# Out:
# 10

# %%
print(x/y)
# Out:
# 2.5

# %%
print(x%y)
# Out:
# 1

# %%
print(x//y)
# Out:
# 2

# %%
print(x**y)
# Out:
# 25

# %% [markdown]
# title() Function

# %%
name="murat simsek"
print(name.title())
# Out:
# Murat Simsek

# %% [markdown]
# upper() and lower() function

# %%
print(name.upper())
# Out:
# MURAT SIMSEK

# %%
print(name.lower())
# Out:
# murat simsek

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=5
y=2

# %%
x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
x<=y
# Out:
# False

# %%
x!=y
# Out:
# True

# %% [markdown]
# #Logical Operator
#
#
# 1.   Logical operators are used to combine conditional statements
#
# 2.   Gives a Boolean result (True/False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=5
y=2

# %%
y<6 and x<10
# Out:
# True

# %%
y<6 and x>10
# Out:
# False

# %%
y<6 or x<10
# Out:
# True

# %%
y<6 or x>10
# Out:
# True

# %%
not(x>10 and y>3)
# Out:
# True
